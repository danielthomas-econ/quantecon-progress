# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x,y,'y-', label="$y=\sin(x)$")
plt.legend(loc="center")
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\daniel\AppData\Local\Temp\ipykernel_3128\501046967.py:5: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(x,y,'y-', label="$y=\sin(x)$")

# %%
z = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x,y,'r-', alpha=0.1, label = "sin x")
ax.plot(x,z,'b-', alpha = 0.8, label = "cos x")
ax.set_yticks(np.linspace(-1,1,5))
ax.set_xticks(np.linspace(0,10, 11))
ax.set_title("Learning matplotlib")
plt.legend()
plt.show()

# %%
from scipy.stats import norm
from random import uniform

fig, ax = plt.subplots()

x = np.linspace(-4,4,150)
for i in range(3):
    m, s = uniform(-1,1), uniform(1,2) # mean and sd
    y = norm.pdf(x, loc=m, scale=s) # creates 3 pdfs with the above mean and sd
    current_label = f"$\mu$ = {m:.2}, $\sigma$={s:.2}"
    ax.plot(x,y, label = current_label)

ax.legend()
plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\daniel\AppData\Local\Temp\ipykernel_3128\1212161150.py:10: SyntaxWarning: invalid escape sequence '\m'
#   current_label = f"$\mu$ = {m:.2}, $\sigma$={s:.2}"
# C:\Users\daniel\AppData\Local\Temp\ipykernel_3128\1212161150.py:10: SyntaxWarning: invalid escape sequence '\s'
#   current_label = f"$\mu$ = {m:.2}, $\sigma$={s:.2}"

# %%
# multiple subplots

num_rows, num_cols = 3,2
fig, axes = plt.subplots(num_rows, num_cols, figsize = (10,10))
x = np.linspace(-4,4,150)
for i in range(num_rows):
    for j in range(num_cols):
        m,s = uniform(-1,1), uniform(1,2) # mean and sd again
        y = norm.pdf(x, loc=m, scale=s)
        axes[i,j].set_xticks([-4,0,4])
        axes[i,j].set_yticks([])
        cur_title = f"$\mu$ = {m:.2}, $\sigma$ = {s:.2}"
        axes[i,j].set_title(cur_title)
        axes[i,j].plot(x,y)
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\daniel\AppData\Local\Temp\ipykernel_3128\2722541254.py:12: SyntaxWarning: invalid escape sequence '\m'
#   cur_title = f"$\mu$ = {m:.2}, $\sigma$ = {s:.2}"
# C:\Users\daniel\AppData\Local\Temp\ipykernel_3128\2722541254.py:12: SyntaxWarning: invalid escape sequence '\s'
#   cur_title = f"$\mu$ = {m:.2}, $\sigma$ = {s:.2}"

# %%
def subplots():
    "Custom subplots with axes through the origin"
    fig, ax = plt.subplots()

    # Set the axes through the origin
    for spine in ['left', 'bottom']:
        ax.spines[spine].set_position('zero')
    for spine in ['right', 'top']:
        ax.spines[spine].set_color('none')

    ax.grid()
    return fig, ax

fig, ax = subplots() # uses our local version of subplots
x = np.linspace(-5,5,100)
y = np.exp(x)
ax.plot(x,y,'g-',label="exponential")
ax.legend()
plt.show()

# %% [markdown]
# # Exercise 12.1
# Plot the function $f(x)=\cos(\pi \theta x)\exp(-x)$ over the interval $[0,5]$ for each $\theta$ in `np.linspace(0,2,10)`. Place all the curves in the same figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
thetavals = np.linspace(0,2,10)
x = np.linspace(0,5,100)

for θ in thetavals:
    f = np.cos(np.pi*θ*x)*np.exp(-x)
    plt.xlim=(0,5)
    plt.ylim=(-1,1)
    ax.plot(x,f)
    
plt.plot()
# Out:
# []
